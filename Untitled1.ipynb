# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error
from tqdm.notebook import *

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
hp = pd.read_csv("~/.kaggle/house.csv", index_col=0)
print("Dataset Info:")
print(hp.info())
print("\nFirst 5 rows:")
print(hp.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20640 entries, -122.23 to -121.24
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   latitude            20640 non-null  float64
#  1   housing_median_age  20640 non-null  float64
#  2   total_rooms         20640 non-null  float64
#  3   total_bedrooms      20433 non-null  float64
#  4   population          20640 non-null  float64
#  5   households          20640 non-null  float64
#  6   median_income       20640 non-null  float64
#  7   median_house_value  20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.6+ MB
# None
#
# First 5 rows:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.23       37.88                41.0        880.0           129.0
# -122.22       37.86                21.0       7099.0          1106.0
# ...

# %%
print("\nMissing Values:")
missing_values = hp.isnull().sum()
missing_percentage = (missing_values / len(hp)) * 100
print(missing_percentage)


columns_to_drop = missing_percentage[missing_percentage > 80].index
hp = hp.drop(columns=columns_to_drop)
print(f"\nDropped columns with >80% missing values: {columns_to_drop}")
# Out:
# Missing Values:
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        1.002907
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64
#
# Dropped columns with >80% missing values: Index([], dtype='object')

# %%
numerical_cols = hp.select_dtypes(include=['int64', 'float64']).columns
hp[numerical_cols] = hp[numerical_cols].fillna(hp[numerical_cols].mean())

# %%
categorical_cols = hp.select_dtypes(include=['object']).columns
hp = pd.get_dummies(hp, columns=categorical_cols, drop_first=True)

# %%
y = hp['median_house_value']
X = hp.drop('median_house_value', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
y_train_pred_lr = lr.predict(X_train_scaled)
y_test_pred_lr = lr.predict(X_test_scaled)
print("\nLinear Regression:")
print(f"Train R^2 Score: {lr.score(X_train_scaled, y_train):.4f}")
print(f"Test R^2 Score: {lr.score(X_test_scaled, y_test):.4f}")
# Out:
# Linear Regression:
# Train R^2 Score: 0.6352
# Test R^2 Score: 0.6288

# %%
train_rmse_lr = np.sqrt(mean_squared_error(y_train, y_train_pred_lr))
test_rmse_lr = np.sqrt(mean_squared_error(y_test, y_test_pred_lr))
print("\nLinear Regression RMSE:")
print(f"Train RMSE: {train_rmse_lr:.2f}")
print(f"Test RMSE: {test_rmse_lr:.2f}")
print("Interpretation: The test RMSE is significantly higher than the train RMSE, indicating overfitting.")
# Out:
# Linear Regression RMSE:
# Train RMSE: 69905.15
# Test RMSE: 69801.38
# Interpretation: The test RMSE is significantly higher than the train RMSE, indicating overfitting.

# %%
df_resultat_ridge = []
alphas = [0.01, 0.05, 0.1, 0.3, 0.8, 1, 5, 10, 15, 20, 35, 50]

for alpha in tqdm_notebook(alphas):
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)
    y_pred = ridge.predict(X_test_scaled)
    mse_result = mean_squared_error(y_test, y_pred)
    res = pd.DataFrame({"Features": X_train.columns, "Coefficients": ridge.coef_})
    res["alpha"] = alpha
    res["mse"] = mse_result
    df_resultat_ridge.append(res)

df_resultat_ridge = pd.concat(df_resultat_ridge)

alphas_result=df_resultat_ridge.groupby("alpha")['mse'].mean()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(8, 6))
plt.plot(alphas_result.index, alphas_result.values, marker='o')
plt.xlabel('Alpha')
plt.ylabel('Mean Squared Error')
plt.title('Ridge Regression MSE vs Alpha')
plt.xscale('log')
plt.grid(True)
plt.show()

# %%
best_alpha = alphas_result.idxmin()
ridge_best = Ridge(alpha=best_alpha)
ridge_best.fit(X_train_scaled, y_train)
y_train_pred_ridge = ridge_best.predict(X_train_scaled)
y_test_pred_ridge = ridge_best.predict(X_test_scaled)
print("\nRidge Regression (Best Alpha):")
print(f"Best Alpha: {best_alpha}")
print(f"Train R^2 Score: {ridge_best.score(X_train_scaled, y_train):.4f}")
print(f"Test R^2 Score: {ridge_best.score(X_test_scaled, y_test):.4f}")
# Out:
# Ridge Regression (Best Alpha):
# Best Alpha: 50.0
# Train R^2 Score: 0.6352
# Test R^2 Score: 0.6291

# %%
train_rmse_ridge = np.sqrt(mean_squared_error(y_train, y_train_pred_ridge))
test_rmse_ridge = np.sqrt(mean_squared_error(y_test, y_test_pred_ridge))
print("\nRidge Regression RMSE:")
print(f"Train RMSE: {train_rmse_ridge:.2f}")
print(f"Test RMSE: {test_rmse_ridge:.2f}")
print("Interpretation: The test RMSE is closer to the train RMSE compared to Linear Regression, indicating reduced overfitting.")
# Out:
# Ridge Regression RMSE:
# Train RMSE: 69910.25
# Test RMSE: 69776.54
# Interpretation: The test RMSE is closer to the train RMSE compared to Linear Regression, indicating reduced overfitting.

# %%
param_grid = {
    'alpha': [0.01, 0.02, 0.05, 0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
    'l1_ratio': np.arange(0.0, 1.01, 0.05)
}
elastic_net = ElasticNet()
grid_search = GridSearchCV(elastic_net, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=ElasticNet(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.02, 0.05, 0.1, 0.5, 1.0, 2.0, 5.0,
#                                    10.0],
#                          'l1_ratio': array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])},
#              scoring='neg_mean_squared_error')

# %%
alphas = grid_search.cv_results_['param_alpha'].data
l1_ratios = grid_search.cv_results_['param_l1_ratio'].data
scores = -grid_search.cv_results_['mean_test_score']

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

colors = scores

scatter=ax.scatter(alphas, l1_ratios, scores, c=colors, cmap='viridis')
fig.colorbar(scatter)
ax.set_xlabel('Alpha')
ax.set_ylabel('L1 Ratio')
ax.set_zlabel('Score')
ax.set_title('Results of the GridSearch')

plt.show();

# %%
best_params = grid_search.best_params_
elastic_net_best = ElasticNet(alpha=best_params['alpha'], l1_ratio=best_params['l1_ratio'])
elastic_net_best.fit(X_train_scaled, y_train)
y_train_pred_en = elastic_net_best.predict(X_train_scaled)
y_test_pred_en = elastic_net_best.predict(X_test_scaled)
print("\nElasticNet (Best Parameters):")
print(f"Best Parameters: {best_params}")
print(f"Train R^2 Score: {elastic_net_best.score(X_train_scaled, y_train):.4f}")
print(f"Test R^2 Score: {elastic_net_best.score(X_test_scaled, y_test):.4f}")
# Out:
# ElasticNet (Best Parameters):
# Best Parameters: {'alpha': 0.01, 'l1_ratio': np.float64(0.45)}
# Train R^2 Score: 0.6351
# Test R^2 Score: 0.6291

# %%
train_rmse_en = np.sqrt(mean_squared_error(y_train, y_train_pred_en))
test_rmse_en = np.sqrt(mean_squared_error(y_test, y_test_pred_en))
print("\nElasticNet RMSE:")
print(f"Train RMSE: {train_rmse_en:.2f}")
print(f"Test RMSE: {test_rmse_en:.2f}")
print("Interpretation: The ElasticNet model balances L1 and L2 penalties, potentially further reducing overfitting compared to Ridge, depending on the optimal alpha and l1_ratio.")
# Out:
# ElasticNet RMSE:
# Train RMSE: 69917.35
# Test RMSE: 69769.88
# Interpretation: The ElasticNet model balances L1 and L2 penalties, potentially further reducing overfitting compared to Ridge, depending on the optimal alpha and l1_ratio.
